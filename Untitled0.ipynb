# %% [markdown]
# <a href="https://colab.research.google.com/github/seungjun0423/PythonPractice/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
def fbs(a):
  params ={
    "date": "2022-10-23",
    "maryblyts-response-type": "specificDateMaryblytsStatus",
    "plant": a,
  };
  api = "https://fireblight.org/fireblight/getMaryblyts";
  response = requests.get(api, params)
  data=response.json()
  return data

fbs("apple")
# Out:
# {'items': [{'st_id': 1,
#    'year': 2022,
#    'code': 1701,
#    'name': '가평군 가평읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.500637166144,37.8462172893295',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2,
#    'year': 2022,
#    'code': 1724,
#    'name': '고양시 덕양구',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.870367153386,37.649186447575',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 3,
#    'year': 2022,
#    'code': 1702,
#    'name': '고양시 구산동',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.7007004677447,37.6745378617658',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 4,
#    'year': 2022,
#    'code': 1703,
#    'name': '광주시 목현동',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.2339451285324,37.4323154274877',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 5,
#    'year': 2022,
#    'code': 1727,
#    'name': '수원시 서둔동',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.9929953999386,37.2736097877224',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 6,
#    'year': 2022,
#    'code': 1729,
#    'name': '연천군 신서면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.1033466271985,38.1715790836453',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 7,
#    'year': 2022,
#    'code': 1733,
#    'name': '포천시 영북면',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.6086725939798,37.1203540140656',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 8,
#    'year': 2022,
#    'code': 1730,
#    'name': '이천시 장호원',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.613817,37.149185',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 9,
#    'year': 2022,
#    'code': 1732,
#    'name': '화성시 마도면',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.4941633,36.8654786',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 10,
#    'year': 2022,
#    'code': 1726,
#    'name': '이천시 진암리',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.6095615,37.1211258',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 11,
#    'year': 2022,
#    'code': 1704,
#    'name': '김포시 월곶면',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.5561499880861,37.6948926398265',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 12,
#    'year': 2022,
#    'code': 1708,
#    'name': '남양주 진건읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.1932722632196,37.6497750888798',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 13,
#    'year': 2022,
#    'code': 1709,
#    'name': '시흥시 하중동',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.8079020007737,37.4010444413861',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 14,
#    'year': 2022,
#    'code': 1725,
#    'name': '안산시 상록구',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.8445415721878,37.3003565965582',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 15,
#    'year': 2022,
#    'code': 1710,
#    'name': '안산시 단원구',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.5911897298652,37.2489298012975',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 16,
#    'year': 2022,
#    'code': 1711,
#    'name': '안성시 보개면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.2877656132125,37.0239266061455',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 17,
#    'year': 2022,
#    'code': 1712,
#    'name': '양주시 광적면',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.9726989790633,37.8204658690557',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 18,
#    'year': 2022,
#    'code': 1713,
#    'name': '양평군 양평읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.5129549811034,37.5089763605439',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 19,
#    'year': 2022,
#    'code': 1714,
#    'name': '여주시 상거동',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.6379650326619,37.252264366119',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 20,
#    'year': 2022,
#    'code': 1715,
#    'name': '연천군 연천읍',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.0784322641421,38.0843632868409',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 21,
#    'year': 2022,
#    'code': 1716,
#    'name': '용인시 처인구',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.2989065316915,37.1738676491051',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 22,
#    'year': 2022,
#    'code': 1719,
#    'name': '이천시 중리동',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.4330550458393,37.2726129367864',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 23,
#    'year': 2022,
#    'code': 1720,
#    'name': '파주시 아동동',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.7961808006711,37.7646989633352',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 24,
#    'year': 2022,
#    'code': 1721,
#    'name': '평택시 오성면',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.980651034993,37.0125779189737',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 25,
#    'year': 2022,
#    'code': 1722,
#    'name': '포천시 신북면',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.2257303196088,37.9236499726384',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 26,
#    'year': 2022,
#    'code': 1723,
#    'name': '화성시 장안면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.9500418048756,37.2203094187771',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 27,
#    'year': 2022,
#    'code': 2702,
#    'name': '강릉시 연곡면 동덕리',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.8440189637843,37.8524210032132',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 28,
#    'year': 2022,
#    'code': 2743,
#    'name': '철원군 갈말읍 문혜리',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.322013,38.162629',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 29,
#    'year': 2022,
#    'code': 2742,
#    'name': '태백시 매봉산',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.9651492465881,37.2230846246554',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 30,
#    'year': 2022,
#    'code': 2704,
#    'name': '강릉 안반덕이',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.7374833157384,37.6190656420553',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 31,
#    'year': 2022,
#    'code': 2724,
#    'name': '평창군 운교리',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.4491864935426,37.5372955099655',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 32,
#    'year': 2022,
#    'code': 2723,
#    'name': '평창군 진부면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.5943015068459,37.6700556861615',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 33,
#    'year': 2022,
#    'code': 2718,
#    'name': '태백 귀네미골',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '129.0052808706402,37.3355175172755',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 34,
#    'year': 2022,
#    'code': 2727,
#    'name': '홍천군 자운리',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.380235437699,37.7175217709029',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 35,
#    'year': 2022,
#    'code': 2735,
#    'name': '동해시 북평동',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '129.1188242164255,37.4852015839046',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 36,
#    'year': 2022,
#    'code': 2705,
#    'name': '삼척시 근덕면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '129.2311242265398,37.3841662952594',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 37,
#    'year': 2022,
#    'code': 2739,
#    'name': '삼척시 미로면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '129.1062461994681,37.4102683358592',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 38,
#    'year': 2022,
#    'code': 2707,
#    'name': '속초시 대포동',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.5997099208545,38.1691946504317',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 39,
#    'year': 2022,
#    'code': 2736,
#    'name': '양구군 만대리',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.08108,38.15287',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 40,
#    'year': 2022,
#    'code': 2740,
#    'name': '양구군 후리',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.08334,38.17512',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 41,
#    'year': 2022,
#    'code': 2709,
#    'name': '양양군 손양면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.6336087441451,38.0749083057415',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 42,
#    'year': 2022,
#    'code': 2711,
#    'name': '영월군 영월읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.4771644502047,37.1676363036401',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 43,
#    'year': 2022,
#    'code': 2712,
#    'name': '원주시 흥업면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.9150318159867,37.2957692385357',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 44,
#    'year': 2022,
#    'code': 2731,
#    'name': '인제군 인제읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.1670186832702,38.059745207457',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 45,
#    'year': 2022,
#    'code': 2732,
#    'name': '정선군 임계면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.8763286550375,37.5047184690369',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 46,
#    'year': 2022,
#    'code': 2734,
#    'name': '정선군 정선읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.6539509072861,37.4233251577744',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 47,
#    'year': 2022,
#    'code': 2733,
#    'name': '정선군 신동읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.5847705843219,37.2598799699101',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 48,
#    'year': 2022,
#    'code': 2715,
#    'name': '철원군 동송읍',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.25026,38.20324',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 49,
#    'year': 2022,
#    'code': 2716,
#    'name': '춘천시 신북읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.753771572878,37.9340000414096',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 50,
#    'year': 2022,
#    'code': 2717,
#    'name': '태백시 황지동',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.9748558435026,37.1561904528505',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 51,
#    'year': 2022,
#    'code': 2737,
#    'name': '평창군 여만리',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.3940232310351,37.3771570073961',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 52,
#    'year': 2022,
#    'code': 2728,
#    'name': '홍천군 화동리',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.859436730857,37.7056620468048',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 53,
#    'year': 2022,
#    'code': 2729,
#    'name': '화천군 화천읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.6944895475391,38.1101301425975',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 54,
#    'year': 2022,
#    'code': 2730,
#    'name': '횡성군 공근면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.9606639292125,37.5275072970014',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 55,
#    'year': 2022,
#    'code': 3708,
#    'name': '충주시 산척면 명서리',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.0072284,37.0728931',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 56,
#    'year': 2022,
#    'code': 7732,
#    'name': '영동군 심천면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.7163816470953,36.2068785810895',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 57,
#    'year': 2022,
#    'code': 3700,
#    'name': '옥천군 옥천읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.5965388033857,36.2999700454315',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 58,
#    'year': 2022,
#    'code': 3701,
#    'name': '음성군 소이면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.7617580145978,36.9136667231297',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 59,
#    'year': 2022,
#    'code': 3702,
#    'name': '제천시 봉양읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.1766830256354,37.1615680049508',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 60,
#    'year': 2022,
#    'code': 3703,
#    'name': '진천군 진천읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.4297729675491,36.8538590918434',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 61,
#    'year': 2022,
#    'code': 3705,
#    'name': '청주시 남일면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.5064587060118,36.5879445321045',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 62,
#    'year': 2022,
#    'code': 3707,
#    'name': '충주시 달천동',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.8972865499529,36.9501504496532',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 63,
#    'year': 2022,
#    'code': 3704,
#    'name': '청원군 오창읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.4650762159567,36.7230478063796',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 64,
#    'year': 2022,
#    'code': 4717,
#    'name': '계룡시 두마면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.2772604357715,36.2616917568172',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 65,
#    'year': 2022,
#    'code': 4710,
#    'name': '공주시 우성면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.0992424997308,36.4934052910514',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 66,
#    'year': 2022,
#    'code': 4721,
#    'name': '천안시 입장면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.21226,36.923693',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 67,
#    'year': 2022,
#    'code': 4701,
#    'name': '금산군 금성면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.4940871391244,36.1258495124213',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 68,
#    'year': 2022,
#    'code': 4718,
#    'name': '논산시 광석면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.0856028936476,36.2279532874194',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 69,
#    'year': 2022,
#    'code': 4703,
#    'name': '당진시 당진읍',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.6496889758083,36.913772333021',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 70,
#    'year': 2022,
#    'code': 4704,
#    'name': '보령시 주교면',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.5660111208969,36.3911574489337',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 71,
#    'year': 2022,
#    'code': 4705,
#    'name': '부여군 규암면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.8426299599541,36.2591519253658',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 72,
#    'year': 2022,
#    'code': 4719,
#    'name': '아산시 염치읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.9679648119612,36.8257331962636',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 73,
#    'year': 2022,
#    'code': 4708,
#    'name': '예산군 신암면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.8144526672071,36.7420955286788',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 74,
#    'year': 2022,
#    'code': 4709,
#    'name': '천안시 목천읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.207218306364,36.7752704492332',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 75,
#    'year': 2022,
#    'code': 4720,
#    'name': '천안시 성환읍',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.1300607691358,36.9599390008045',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 76,
#    'year': 2022,
#    'code': 4714,
#    'name': '청양군 청양읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.7957000256768,36.4254569074213',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 77,
#    'year': 2022,
#    'code': 4715,
#    'name': '태안군 태안읍',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.3047794534231,36.7328542150789',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 78,
#    'year': 2022,
#    'code': 4716,
#    'name': '홍성군 홍성읍',
#    'type': 'rda',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.5792136290832,36.6026328729866',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 79,
#    'year': 2022,
#    'code': 5710,
#    'name': '완주군 이서면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.045590795387,35.8288117054826',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 80,
#    'year': 2022,
#    'code': 5713,
#    'name': '부안군 계화면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.6695858352487,35.7728137124119',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 81,
#    'year': 2022,
#    'code': 5714,
#    'name': '남원시 운봉읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.5284342232906,35.4385122998086',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 82,
#    'year': 2022,
#    'code': 5873,
#    'name': '완주군 반교리',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.032277,35.83029',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 83,
#    'year': 2022,
#    'code': 5715,
#    'name': '장수군 개정리',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.5190849,35.6222192',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 84,
#    'year': 2022,
#    'code': 5716,
#    'name': '군산시 개정면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.46785,35.57674',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 85,
#    'year': 2022,
#    'code': 5701,
#    'name': '김제시 부량면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.8514645218314,35.7464476048752',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 86,
#    'year': 2022,
#    'code': 5702,
#    'name': '남원시 이백면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.4379507475487,35.4260870659258',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 87,
#    'year': 2022,
#    'code': 5703,
#    'name': '무주군 무주읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.6778725878501,36.0059115051076',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 88,
#    'year': 2022,
#    'code': 5709,
#    'name': '순창군 구림면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.0412064846703,35.4382172716685',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 89,
#    'year': 2022,
#    'code': 5704,
#    'name': '완주군 고산면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.2215200330368,35.9849417876042',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 90,
#    'year': 2022,
#    'code': 5712,
#    'name': '익산시 함열읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.9590073246827,36.0412522230982',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 91,
#    'year': 2022,
#    'code': 5711,
#    'name': '임실군 신평면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.265885835604,35.6562711461021',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 92,
#    'year': 2022,
#    'code': 5705,
#    'name': '장수군 장수읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.5115466970836,35.6198102073102',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 93,
#    'year': 2022,
#    'code': 5706,
#    'name': '정읍시 정우면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.8962520008391,35.6208470015435',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 94,
#    'year': 2022,
#    'code': 5707,
#    'name': '진안군 진안읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.4374515238582,35.7603072537597',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 95,
#    'year': 2022,
#    'code': 6736,
#    'name': '강진군 군동면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.7900304,34.6438126',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 96,
#    'year': 2022,
#    'code': 6702,
#    'name': '고흥군 풍양면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.2581180596731,34.5664897936253',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 97,
#    'year': 2022,
#    'code': 6731,
#    'name': '곡성군 오곡면',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.3034442342975,35.2736472853422',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 98,
#    'year': 2022,
#    'code': 6705,
#    'name': '구례군 구례읍',
#    'type': 'rda',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
# ...
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2451,
#    'year': 2022,
#    'code': 2101170001,
#    'name': '당진시 신평면 예전길',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.751424571497,36.8669722352902',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2452,
#    'year': 2022,
#    'code': 2101170002,
#    'name': '당진시 순성면 다복길',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.73111609649,36.8434453193204',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2453,
#    'year': 2022,
#    'code': 2101170003,
#    'name': '당진시 순성면 활량길',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.703727283717,36.8323468351653',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2454,
#    'year': 2022,
#    'code': 2101170004,
#    'name': '당진시 송악읍 순성로',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.731284658795,36.8661096690812',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2455,
#    'year': 2022,
#    'code': 2101170005,
#    'name': '당진시 석문면 석문방조제로',
#    'type': 'fireblight',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.546210268662,37.0171429025955',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2456,
#    'year': 2022,
#    'code': 2101170006,
#    'name': '당진시 합덕읍 상개길',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.753480436956,36.7696616671866',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2457,
#    'year': 2022,
#    'code': 2101170007,
#    'name': '당진시 정미면 봉성길',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.545659464882,36.8399822872938',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2458,
#    'year': 2022,
#    'code': 2101170008,
#    'name': '당진시 우강면 은골1길',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.769104118078,36.8164525149612',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2459,
#    'year': 2022,
#    'code': 2101170009,
#    'name': '당진시 정미면 한새울로',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.539334270385,36.8691480589523',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2460,
#    'year': 2022,
#    'code': 2101170010,
#    'name': '당진시 순성면 서두물길',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '126.750997340223,36.8551679076011',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2461,
#    'year': 2022,
#    'code': 2101160001,
#    'name': '상주시 은척면 두곡리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.078946886173,36.5743678316432',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2462,
#    'year': 2022,
#    'code': 2101160002,
#    'name': '상주시 공검면 역곡리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.171236821968,36.5368568704062',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2463,
#    'year': 2022,
#    'code': 2101160003,
#    'name': '상주시 공검면 동막리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.124040955317,36.5107175424419',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2464,
#    'year': 2022,
#    'code': 2101160004,
#    'name': '상주시 외서면 연봉리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.17555332522,36.4943423954128',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2465,
#    'year': 2022,
#    'code': 2101160005,
#    'name': '상주시 사벌국면 용담리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.204313612233,36.4905637616418',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2466,
#    'year': 2022,
#    'code': 2101160006,
#    'name': '상주시 낙동면 운평리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.213659409944,36.3712718458466',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2467,
#    'year': 2022,
#    'code': 2101160007,
#    'name': '상주시 청리면 청하리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.129074567444,36.3323877564371',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2468,
#    'year': 2022,
#    'code': 2101160008,
#    'name': '상주시 화서면 상곡리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.968354060892,36.4539735270222',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2469,
#    'year': 2022,
#    'code': 2101160009,
#    'name': '상주시 화남면 중눌리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.874028635086,36.3972985778016',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2470,
#    'year': 2022,
#    'code': 2101160010,
#    'name': '상주시 모서면 지산리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.945571103481,36.3493368055154',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2471,
#    'year': 2022,
#    'code': 2101140001,
#    'name': '의성군 다인면 달제리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.396127309035,36.4576097873362',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2472,
#    'year': 2022,
#    'code': 2101140002,
#    'name': '의성군 단밀면 용곡리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.399978423979,36.3508412522769',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2473,
#    'year': 2022,
#    'code': 2101140003,
#    'name': '의성군 비안면 장춘리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.514407188587,36.3294760263987',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2474,
#    'year': 2022,
#    'code': 2101140004,
#    'name': '의성군 봉양면 분토리',
#    'type': 'fireblight',
#    'bbs_max_status': None,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.648685890558,36.3215670254168',
#    'bbs_max_status_kor': '기간아님',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2475,
#    'year': 2022,
#    'code': 2101140005,
#    'name': '의성군 안평면 괴산리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.603334229543,36.3801679141163',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2476,
#    'year': 2022,
#    'code': 2101140006,
#    'name': '의성군 단촌면 병방리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.723242374228,36.4324816095709',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2477,
#    'year': 2022,
#    'code': 2101140007,
#    'name': '의성군 점곡면 동변리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.782365320903,36.4245006453646',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2478,
#    'year': 2022,
#    'code': 2101140009,
#    'name': '의성군 금성면 도경리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.660989977768,36.2212034071054',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2479,
#    'year': 2022,
#    'code': 2101140010,
#    'name': '의성군 춘산면 금오리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.884685996448,36.2110517116404',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2480,
#    'year': 2022,
#    'code': 2101140008,
#    'name': '의성군 옥산면 구성리',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '128.80842257145,36.3857220232857',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   {'st_id': 2481,
#    'year': 2022,
#    'code': 2101100007,
#    'name': '연천군 미산면 청정로',
#    'type': 'fireblight',
#    'bbs_max_status': 1.0,
#    'cms_max_status': 1.0,
#    'cbs_max_status': 1.0,
#    'sbs_max_status': 1.0,
#    'coords': '127.005356419462,38.0543614416605',
#    'bbs_max_status_kor': '꽃 병징 상태',
#    'cms_max_status_kor': '궤양 활성 상태',
#    'cbs_max_status_kor': '궤양 병징 상태',
#    'sbs_max_status_kor': '신초 병징 상태',
#    'belong2region': {},
#    'tm': '2022-10-23',
#    'bir': 0.0,
#    'growth': 1.0,
#    'bir_kor': '기간아님'},
#   ...]}
